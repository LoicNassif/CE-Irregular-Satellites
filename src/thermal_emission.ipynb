# %%
import thermal_emission
import smaxis_vs_time
from numpy import linspace, logspace

# %%
M0 = 10 * 7.34767309e22; Dt = 100.; Dmax = 250000.; L_s = 20 * 3.828e26;
M_s = 1.86 * 1.989e30; M_pl = 1 * 1.89587112e27; a_pl = 50 * 1.496e11
R_pl = 6.9911e7; eta = 0.4; Nstr = 6.; d_pl = 50 * 3.086e16

argv = [M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl]

# %% [markdown]
# ### Varying Semi-Major Axis

# %%
t = 4.5e9
lamb = 1e-4
aplv = linspace(0.5 * 1.496e11, 900 * 1.496e11)
thermal_emission.main(argv, lamb, t, a_plv = aplv)

# %% [markdown]
# ### Varying Time

# %%
t = linspace(1e6, 10e10, 500)
lamb = 1e-4
thermal_emission.main(argv, lamb, t)

# %% [markdown]
# ### Varying Initial Swarm Mass

# %%
t = 4.5e9
lamb = 1e-4
Mtotv = linspace(0.01 * 7.34767309e22, 100 * 7.34767309e22, 1000)
thermal_emission.main(argv, lamb, t, Mtot0 = Mtotv)

# %% [markdown]
# ### Time vs Semi-major axis such that t = 1/Rcc

# %%
t = linspace(1e6, 10e10, 500)
lamb = 1e-4
smaxis_vs_time.main(argv, lamb, t)
