# %%
from swarms import SizeDistribution
from swarms import CollSwarm
from numpy import linspace, zeros, logspace, array
import matplotlib.pyplot as plt

# %% [markdown]
# # Jupiter: An Example
#
# For the following plots, the specifications of Jupiter will be used to demonstrate the different possible plots that swarms.py can produce.

# %%
Dmin = 12e-6; Dmax = 15e4; M_init = 7.37307e19

jupiter = SizeDistribution(Dmin, Dmax, M0=M_init)

# %%
initial_swarm_mass = jupiter.Mtot()
initial_swarm_area = jupiter.Atot()
print("Swarm mass = {0:.5e} kg".format(initial_swarm_mass))
print("Swarm area = {0:.5e} m^2".format(initial_swarm_area))
# Out:
# Swarm mass = 7.39324e+19 kg
# Swarm area = 9.18122e+16 m^2

# %% [markdown]
# ## Area Plot
#
# One can plot the total surface area of a swarm over time by repeatedly updating the swarm for every needed time step and record the specific area at that time. There is the option to specify a dynamic maximum object size that would decrease over time as specified in Kennedy 2010.

# %%
M0 = 0.002 * 7.34767309e22; Dt = 100.; Dmax = 150000.; L_s = 3.828e26;
M_s = 1.989e30; M_pl = 1.89587112e27; a_pl = 7.7792e11
R_pl = 6.9911e7; eta = 0.4; Nstr = 6.; d_pl = a_pl

jupiter_correct = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=True, alpha=.12)
jupiter_no_correct = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=False, alpha=.12)

# %%
time = linspace(0, 1e10, 50000)
area_correct = zeros(50000)
area_no_correct = zeros(50000)

print(jupiter_correct.Dmin)

for i in range(len(time)):
    a = jupiter_correct.computeAtot()*4.4683677582981e-23 # change units into AU
    b = jupiter_no_correct.computeAtot()*4.4683677582981e-23 # change units into AU
    area_correct[i] = a
    area_no_correct[i] = b
    jupiter_correct.updateSwarm(time[i])
    jupiter_no_correct.updateSwarm(time[i])
# Out:
# 1.236153477581652e-05

# %%
plt.loglog(time, area_correct, 'r', label="corrected stranding evolution")
plt.loglog(time, area_no_correct, ls='--', label="static Dc")
plt.axvline(jupiter_correct.tnleft, color='g', ls='--', label="first stranded object")
plt.xlabel("time [yr]")
plt.ylabel("area [AU^2]")
plt.title("Area of Circumplanetary Swarm - Jupiter")
plt.legend()
plt.xlim([2e5, 9e9])
plt.ylim([5e-9, 1e-5])
plt.show()

# %% [markdown]
# ## Number Density Plot
#
# Since it is possible to compute the number of objects in the swarm at any time with our code, an other possible plot that can be made is a size-distribution plot for logarithmic spaced times.

# %%
jupiter_num = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=True, alpha=1.2)

# %%
drange = linspace(0.1, 250000, 5000)
time_log = logspace(0, 10, 30)
num_distribution = []
Dc_list = []
for i in range(len(time_log)):
    #jupiter_num.tnleft = 0.5e8
    jupiter_num.updateSwarm(time_log[i])
    num = []
    dcc = []
    for j in range(len(drange)):
        dcc.append(jupiter_num.swarm.Dc)
        num.append(jupiter_num.computen(drange[j]))
    num_distribution.append(num)
    Dc_list.append(dcc)

# %%
drange = array(drange)
for i in range(len(num_distribution)):
    num_dist = []
    prev_drange = []
    for j in range(len(num_distribution[i])):
        #print("drange = ", drange[j])
        #print("Dc = ", Dc_list[j])
        if drange[j] < Dc_list[i][j]:
            prev_drange.append(drange[j])
            num_dist.append(num_distribution[i][j])
    plt.loglog(prev_drange, num_dist)
#plt.loglog(Dc_list)
#print(Dc_list)
plt.xlim([5000, 200000])
plt.ylim([1e-5, 1e-2])
plt.xlabel("size [m]")
plt.ylabel("number density")
plt.title("Number Density in the Circumplanetary Swarm")
plt.show()

# %% [markdown]
# # Observable Quantities

# %% [markdown]
# ## Flux Computations
#
# We now demonstrate the important computations of thermal radiation flux as well as scattering flux produced by both the planet and the circumplanetary swarm. These values are critical, since they are the observable variables. The distance from the solar system, d_pl, used is 10 pc. We take a Jupiter mass planet orbiting an A5 main-sequence star.

# %%
M0 = 10 * 7.34767309e22; Dt = 100.; Dmax = 250000.; L_s = 20 * 3.828e26;
M_s = 1.86 * 1.989e30; M_pl = 1.89587112e27; a_pl = 7.48e12
R_pl = 6.9911e7; eta = 0.4; Nstr = 6.; d_pl = 3.086e17

jupiter5 = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=True, alpha=1.2)

jupiter5.updateSwarm(1e7) # Update the swarm to 4.5e9 years. 

waverange = logspace(-7, -3, 200)
Fth_planet = jupiter5.computeFth(waverange, planet=True)/1e-26
Fth_swarm = jupiter5.computeFth(waverange, swarm=True)/1e-26
Fs_planet = jupiter5.computeFs(waverange, 1., 0.52, planet=True)/1e-26
Fs_swarm = jupiter5.computeFs(waverange, 0.32, 0.08, swarm=True)/1e-26
# Out:
# C:\Users\loloynage\Documents\CE-Irregular-Satellites\swarms.py:270: RuntimeWarning: overflow encountered in exp
#   b = 1/(exp(h*(c/lamb)/(k_B*T)) - 1)

# %%
plt.figure(3)
plt.title('Planet Flux')
plt.loglog(waverange, Fs_planet, label="Scattered")
plt.loglog(waverange, Fth_planet, label="Thermal")
plt.ylim([10e-11, 10e-3])
plt.legend()
plt.show()

plt.figure(4)
plt.title('Dust Flux')
plt.loglog(waverange, Fs_swarm, label="Scattered")
plt.loglog(waverange, Fth_swarm, label="Thermal")
plt.ylim([10e-11, 10e-3])
plt.legend()
plt.show()

# %% [markdown]
# # Evolution of Debris Population

# %%
M0 = 0.001 * 7.3477e22; Dt = 100.; Dmax = 150000.; L_s = 3.828e26;
M_s = 1.989e30; M_pl = 1.89587112e27; a_pl = 7.7792e11
R_pl = 6.9911e7; eta = 0.4; Nstr = 6.; d_pl = a_pl

jupiter6 = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=True, alpha=1.2)

drange = linspace(0.01, 1.5e5, 2500)
drange_Dc_tot = []
#drange = logspace(2, 6, 1000)
time_log = logspace(6, 10, 10)
total_amount = []
# Testing
# num = []
#print(jupiter6.computeNtot(dlow=1000))
# for j in range(len(drange)):
#    num.append(jupiter6.computeNtot(dlow=drange[j]))
# total_amount.append(num)

for i in range(len(time_log)):
    jupiter6.updateSwarm(time_log[i])
    num = []
    drange_Dc = []
    print(i)
    for d in drange:#j in range(len(drange)):
        Xc_val = jupiter6.computeXc()
        Mt = jupiter6.swarm.DMtot(jupiter6.Rcc0, time_log[i], jupiter6.tnleft, Xc_val, jupiter6.M_init, jupiter6.correction)
        jupiter6.swarm.M0 = Mt
        #jupiter6.swarm.compute_kg_from_Mtot(Mt)
        #jupiter6.swarm.compute_ks_from_kg()
        #jupiter6.updateSwarm2(time_log[i], d)
        #print(jupiter6.swarm.M0)
        #if d >= jupiter6.swarm.Dc:
        num.append(jupiter6.computeNtot(dlow=d)) #Make dhigh explicit
        drange_Dc.append(d)
    drange_Dc_tot.append(drange_Dc)
    total_amount.append(num)
# Out:
# 0
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  13590.064696665337
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  5162.074481792717
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  761.204990128197
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  20228.099887955177
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  505.68988365444835
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  24489.804285714283
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  381.4931631073372
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  27911.17260504201
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  336.0822322715958
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  29591.84476190476
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  276.70367269398776
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  32352.949019607837
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  204.7518108701981
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  37094.84546218487
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  133.73173958040286
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  44837.942184873944
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  101.1668687329333
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  50600.24672268907
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  81.21197678613783
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  55522.215182072825
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  63.08012766633376
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  61584.63974789916
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  26.41362056779373
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  84994.0019327731
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  23.497797600238115
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  88295.32224089635
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  23.052350580076606
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  88835.53829131651
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  13.948705786880259
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  102761.1075910364
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  12.831247094309294
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  104981.99579831932
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  12.427254645260517
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  105822.33187675069
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  10.29807293224943
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  110624.25232492996
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  7.882707895807957
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  116986.79691876749
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  4.664488609653676
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  127551.02190476189
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  4.632584936049933
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  127671.06991596636
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  2.533100630819046
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  136434.57473389356
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  1.4917746960380915
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  141536.61521008404
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  0.3760919192073583
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  147719.08778711484
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 1
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  7242.616381240547
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  6782.722633053221
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  3065.710482648557
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  10204.090952380951
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  2849.5797097884465
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  10564.234985994397
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  231.59822081338226
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  34213.69319327731
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  117.7057400382138
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  46278.518319327726
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  79.69654704312028
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  54681.879103641455
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  72.61656968419852
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  56842.743305322125
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ...
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2132514573.3060906
# kg_val =  134552573.22385255
# lower =  0
# upper =  0
# str upper =  3.224027163243143
# qg =  1.7
# k_str =  3.833173184101066
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  83733.49781512604
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2132514573.3060906
# kg_val =  134552573.22385255
# lower =  0
# upper =  0
# str upper =  2.602265785379959
# qg =  1.7
# k_str =  3.833173184101066
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  93697.48274509802
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2132514573.3060906
# kg_val =  134552573.22385255
# lower =  0
# upper =  0
# str upper =  1.8236722181773133
# qg =  1.7
# k_str =  3.833173184101066
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  107863.14806722688
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2132514573.3060906
# kg_val =  134552573.22385255
# lower =  0
# upper =  0
# str upper =  1.3803179592931538
# qg =  1.7
# k_str =  3.833173184101066
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  116866.74890756301
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2132514573.3060906
# kg_val =  134552573.22385255
# lower =  0
# upper =  0
# str upper =  0.7248648922991033
# qg =  1.7
# k_str =  3.833173184101066
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  131572.63028011203
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2132514573.3060906
# kg_val =  134552573.22385255
# lower =  0
# upper =  0
# str upper =  0.546138759969296
# qg =  1.7
# k_str =  3.833173184101066
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  135894.35868347337
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2132514573.3060906
# kg_val =  134552573.22385255
# lower =  0
# upper =  0
# str upper =  0.44688720939343485
# qg =  1.7
# k_str =  3.833173184101066
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  138355.34291316525
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2132514573.3060906
# kg_val =  134552573.22385255
# lower =  0
# upper =  0
# str upper =  0.1867922291104005
# qg =  1.7
# k_str =  3.833173184101066
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  145018.007535014
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2132514573.3060906
# kg_val =  134552573.22385255
# lower =  0
# upper =  0
# str upper =  0.09598395610054772
# qg =  1.7
# k_str =  3.833173184101066
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  147418.96775910363
# 	 dlow > Dc
# ks_val =  2132514573.3060906
# kg_val =  134552573.22385255
# lower =  0
# upper =  0
# str upper =  0.09373274517244382
# qg =  1.7
# k_str =  3.833173184101066
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  147478.9917647059
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2132514573.3060906
# kg_val =  134552573.22385255
# lower =  0
# upper =  0
# str upper =  0.024395906945399462
# qg =  1.7
# k_str =  3.833173184101066
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  149339.73593837535
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc

# %%
print(time_log)
# Out:
# [1.00000000e+06 2.78255940e+06 7.74263683e+06 2.15443469e+07
#  5.99484250e+07 1.66810054e+08 4.64158883e+08 1.29154967e+09
#  3.59381366e+09 1.00000000e+10]

# %%
for i in range(len(total_amount)):
    plt.loglog(drange_Dc_tot[i], total_amount[i], label=i)

plt.legend()
plt.ylim([4e-1, 1e3])
plt.xlim([5e2, 3e5])
plt.show()

# %%
M0 = 10 * 7.34767309e22; Dt = 100.; Dmax = 250000.; L_s = 20 * 3.828e26;
M_s = 1.86 * 1.989e30; M_pl = 1.89587112e27;
R_pl = 6.9911e7; eta = 0.4; Nstr = 6.; d_pl = 3.086e17

Fth_planet = []; Fth_swarm = []; Fs_planet = []; Fs_swarm = []; 
a_pl = linspace(0, 10 * 1.496e11, 100 * 1.496e11, 400)
for i in range(len(a_pl)):
    jupiter5 = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl[i], R_pl, eta, Nstr, d_pl, correction=True, alpha=1.2)
    jupiter5.updateSwarm(1e7) # Update the swarm to 4.5e9 years. 

    waverange = logspace(-7, -3, 200)
    Fth_planet = jupiter5.computeFth(waverange, planet=True)/1e-26
    Fth_swarm = jupiter5.computeFth(waverange, swarm=True)/1e-26
    Fs_planet = jupiter5.computeFs(waverange, 1., 0.52, planet=True)/1e-26
    Fs_swarm = jupiter5.computeFs(waverange, 0.32, 0.08, swarm=True)/1e-26
