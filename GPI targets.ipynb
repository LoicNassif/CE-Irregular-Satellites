# %%
import pandas as pd
from astroquery.simbad import Simbad
df = pd.read_csv('stellarparameters.csv', index_col=0)
df.sort_values(by='Distance_distance')
# Out:
#               star           ra           dec                       comment  \
# 78        eps Eri   03:32:55.8   -09:27:29.7   H-coron (~1 hr); H-coron-pol
# 37        tau Cet     01:44:04     -15:56:14                    H-coron-pol
# 587     HD 209100   22:03:21.7   -56:47:10.0                H-coron (~1 hr)
# 198        GJ 285   07:44:40.2    03:33:08.8                H-coron (~1 hr)
# 499     HIP 89805   18:19:40.1   -63:53:11.6                H-coron (~1 hr)
# 252    BD+01 2447   10:28:55.5    00:50:27.6                H-coron (~1 hr)
# 604        TW PsA   22:56:24.1   -31:33:56.0                H-coron (~1 hr)
# 242     V* AN Sex   10:12:17.6   -03:44:44.3                H-coron (~1 hr)
# 333        61 Vir   13:18:24.3   -18:18:40.3   H-coron (~1 hr); H-coron-pol
# 76      HIP 15457   03:19:21.7    03:22:12.7                H-coron (~1 hr)
# 552        AU Mic   20:45:09.5   -31:20:27.2   H-coron (~1 hr); H-coron-pol
# ...

# %%
ms = pd.read_csv('GPIMdwarfs.csv', index_col=0)
ms
# Out:
#         S_Type  Distance_distance  FLUX_I  FLUX_H  Fe_H_Teff Class  subtype  \
# 45         M1V            27.1928     NaN   7.561       3849     M        1
# 59        M0Ve            48.7648     NaN   7.361       3208     M        0
# 69        M1Ve            19.5600   8.372   6.578       3792     M        1
# 83       M3.0V            16.8022   9.098   7.174       3584     M        3
# 109      M3.3V            15.8328   9.100   7.146       3412     M        3
# 110  M3Ve+M4Ve            11.1100   8.151     NaN          0     M        3
# 114       M0Ve            26.9008   8.177   6.429       4048     M        0
# 151       M1Ve            22.4041   9.337   7.280       3652     M        1
# 193     M0.0Ve            15.0578   7.777   6.092       3940     M        0
# 198     M4.0Ve             5.9874   8.263   6.005       3242     M        4
# 242        M2V             7.7048   7.066   5.258       3651     M        2
# ...

# %%
ms.shape
# Out:
# (23, 10)

# %%
names = df.loc[ms.index]
names
# Out:
#             star           ra           dec                       comment  \
# 45    LP 353-51   02:23:26.6    22:44:06.7                H-coron (~1 hr)
# 59    HIP 12787   02:44:21.3    10:57:41.2                H-coron (~1 hr)
# 69     LTT 1479   03:07:55.7   -28:13:10.9                H-coron (~1 hr)
# 83    HIP 17695   03:47:23.3   -01:58:19.9                H-coron (~1 hr)
# 109   LP 776-25   04:52:24.4   -16:49:21.9                H-coron (~1 hr)
# 110   HIP 22738   04:53:31.2   -55:51:37.1                H-coron (~1 hr)
# 114  CD-57 1054   05:00:47.1   -57:15:25.4                H-coron (~1 hr)
# 151  CD-35 2722   06:09:19.2   -35:49:31.1                H-coron (~1 hr)
# 193   HIP 37288   07:39:23.0    02:11:01.2                H-coron (~1 hr)
# 198      GJ 285   07:44:40.2    03:33:08.8                H-coron (~1 hr)
# 242   V* AN Sex   10:12:17.6   -03:44:44.3                H-coron (~1 hr)
# 252  BD+01 2447   10:28:55.5    00:50:27.6                H-coron (~1 hr)
# ...

# %%
names = names.drop_duplicates()
names.shape
# Out:
# (23, 33)

# %%
ms['Simbadname'] = names['star']
ms
# Out:
#         S_Type  Distance_distance  FLUX_I  FLUX_H  Fe_H_Teff Class  subtype  \
# 45         M1V            27.1928     NaN   7.561       3849     M        1
# 59        M0Ve            48.7648     NaN   7.361       3208     M        0
# 69        M1Ve            19.5600   8.372   6.578       3792     M        1
# 83       M3.0V            16.8022   9.098   7.174       3584     M        3
# 109      M3.3V            15.8328   9.100   7.146       3412     M        3
# 110  M3Ve+M4Ve            11.1100   8.151     NaN          0     M        3
# 114       M0Ve            26.9008   8.177   6.429       4048     M        0
# 151       M1Ve            22.4041   9.337   7.280       3652     M        1
# 193     M0.0Ve            15.0578   7.777   6.092       3940     M        0
# 198     M4.0Ve             5.9874   8.263   6.005       3242     M        4
# 242        M2V             7.7048   7.066   5.258       3651     M        2
# ...

# %%
ms.loc[600, 'SimbadType'] = 'Variable of BY Dra type'

# %%
ms.loc[502, 'SimbadType'] = 'High proper motion star'

# %%
ms.loc[242, 'SimbadType'] = 'Variable of RS CVn type'

# %%
ms.loc[151, 'SimbadType'] = 'Double or Multiple star'

# %%
ms.loc[615, 'SimbadType'] = 'Flare Star'

# %%
ms.loc[510, 'SimbadType'] = 'Spectroscopic Binary'

# %%
ms.loc[298, 'SimbadType'] = 'T Tau-type Star'

# %%
ms.loc[618, 'SimbadType'] = 'Rotationally variable Star'

# %%
ms
# Out:
#         S_Type  Distance_distance  FLUX_I  FLUX_H  Fe_H_Teff Class  subtype  \
# 45         M1V            27.1928     NaN   7.561       3849     M        1
# 59        M0Ve            48.7648     NaN   7.361       3208     M        0
# 69        M1Ve            19.5600   8.372   6.578       3792     M        1
# 83       M3.0V            16.8022   9.098   7.174       3584     M        3
# 109      M3.3V            15.8328   9.100   7.146       3412     M        3
# 110  M3Ve+M4Ve            11.1100   8.151     NaN          0     M        3
# 114       M0Ve            26.9008   8.177   6.429       4048     M        0
# 151       M1Ve            22.4041   9.337   7.280       3652     M        1
# 193     M0.0Ve            15.0578   7.777   6.092       3940     M        0
# 198     M4.0Ve             5.9874   8.263   6.005       3242     M        4
# 242        M2V             7.7048   7.066   5.258       3651     M        2
# ...

# %%
ms.to_csv('GPIMdwarfs_extended.csv', encoding='ascii')

# %%
Mdwarfs = pd.read_csv('GPIMdwarfs_extended.csv', index_col=0)
Mdwarfs
# Out:
#         S_Type  Distance_distance  FLUX_I  FLUX_H  Fe_H_Teff Class  subtype  \
# 45         M1V            27.1928     NaN   7.561       3849     M        1
# 59        M0Ve            48.7648     NaN   7.361       3208     M        0
# 69        M1Ve            19.5600   8.372   6.578       3792     M        1
# 83       M3.0V            16.8022   9.098   7.174       3584     M        3
# 109      M3.3V            15.8328   9.100   7.146       3412     M        3
# 110  M3Ve+M4Ve            11.1100   8.151     NaN          0     M        3
# 114       M0Ve            26.9008   8.177   6.429       4048     M        0
# 151       M1Ve            22.4041   9.337   7.280       3652     M        1
# 193     M0.0Ve            15.0578   7.777   6.092       3940     M        0
# 198     M4.0Ve             5.9874   8.263   6.005       3242     M        4
# 242        M2V             7.7048   7.066   5.258       3651     M        2
# ...

# %%
Mdwarfs.loc[552, 'Moving Group'] = 'Beta Pic'
Mdwarfs.loc[114, 'Moving Group'] = 'Beta Pic'
Mdwarfs.loc[255, 'Moving Group'] = 'TWA'
Mdwarfs.loc[298, 'Moving Group'] = 'TWA'
Mdwarfs
# Out:
#         S_Type  Distance_distance  FLUX_I  FLUX_H  Fe_H_Teff Class  subtype  \
# 45         M1V            27.1928     NaN   7.561       3849     M        1
# 59        M0Ve            48.7648     NaN   7.361       3208     M        0
# 69        M1Ve            19.5600   8.372   6.578       3792     M        1
# 83       M3.0V            16.8022   9.098   7.174       3584     M        3
# 109      M3.3V            15.8328   9.100   7.146       3412     M        3
# 110  M3Ve+M4Ve            11.1100   8.151     NaN          0     M        3
# 114       M0Ve            26.9008   8.177   6.429       4048     M        0
# 151       M1Ve            22.4041   9.337   7.280       3652     M        1
# 193     M0.0Ve            15.0578   7.777   6.092       3940     M        0
# 198     M4.0Ve             5.9874   8.263   6.005       3242     M        4
# 242        M2V             7.7048   7.066   5.258       3651     M        2
# ...

# %%
Mdwarfs.sort_values('Distance_distance')
# Out:
#         S_Type  Distance_distance  FLUX_I  FLUX_H  Fe_H_Teff Class  subtype  \
# 198     M4.0Ve             5.9874   8.263   6.005       3242     M        4
# 252     M2.0Ve             7.0329   7.389   5.605       3640     M        2
# 242        M2V             7.7048   7.066   5.258       3651     M        2
# 552    M1VeBa1             9.7248   6.593   4.831       3742     M        1
# 110  M3Ve+M4Ve            11.1100   8.151     NaN          0     M        3
# 510       M3Ve            11.1359   7.690   5.680       3431     M        3
# 502         M1            14.3787   7.930   6.240       3729     M        1
# 585       M2Ve            14.8604   8.101   6.086       3515     M        2
# 193     M0.0Ve            15.0578   7.777   6.092       3940     M        0
# 109      M3.3V            15.8328   9.100   7.146       3412     M        3
# 615       M2Ve            15.9564   8.599   6.608       3481     M        2
# ...

# %%
customSimbad = Simbad()
customSimbad.remove_votable_fields('coordinates')
customSimbad.get_votable_fields()
# Out:
# ['main_id']

# %%
Simbad.get_field_description ('fe_h')
# Out:
# Stellar parameters (Teff, log(g) and [Fe/H]) taken from the literature.

# %%
customSimbad.add_votable_fields('ra(2;A;ICRS;J2017.5;2000)', 'dec(2;D;ICRS;2017.5;2000)', 'sp', 'distance', 'diameter', 'flux(I)', 'flux(H)', 'fe_h')

# %% [markdown]
# Beta pic MG:
# - Not in GPI: GJ 3305, HD 155555C, AT Mic (HIP 102409, GJ 803), HIP 29964 (AO Men), BD -176128 (AZ Cap)
# - In GPI: HIP 23309, AU Mic

# %%
customSimbad.query_object('HIP 23309')
# Out:
# <Table masked=True length=1>
#   MAIN_ID   RA_2_A_ICRS_J2017_5_2000 ... Fe_H_CatNo     Fe_H_bibcode
#                     "h:m:s"          ...
#    object            str13           ...    str5           str19
# ----------- ------------------------ ... ---------- -------------------
# CD-57  1054            05 00 47.2059 ...            2014MNRAS.443.2561G

# %%
def query(row):
    res = customSimbad.query_object(row['star'])
    res = res.to_pandas()
    row = pd.concat([row, res.loc[0]])
    return row

# %%
df1 = df.loc[0:100]
df1 = df1.apply(query, axis=1)

# %%
df2 = df.loc[100:200]
df2 = df2.apply(query, axis=1)

# %%
df3 = df.loc[200:300]
df3 = df3.apply(query, axis=1)

# %%
df4 = df.loc[300:400]
df4 = df4.apply(query, axis=1)

# %%
df5 = df.loc[400:500]
df5 = df5.apply(query, axis=1)

# %%
df6 = df.loc[500:600]
df6 = df6.apply(query, axis=1)

# %%
df7 = df.loc[600:700]
df7 = df7.apply(query, axis=1)

# %%
stellarpar = pd.concat([df1, df2, df3, df4, df5, df6, df7])
stellarpar.tail()
# Out:
#             star           ra           dec                       comment  \
# 626  HIP 117219   23:46:01.2   -40:10:56.9                H-coron (~1 hr)
# 627  HIP 117452   23:48:55.6   -28:07:49.0   H-coron (~1 hr); H-coron-pol
# 628  HIP 117481   23:49:19.6   -27:51:14.9   H-coron (~1 hr); H-coron-pol
# 629  HIP 118008   23:56:10.7   -39:03:08.4   H-coron (~1 hr); H-coron-pol
# 630  HIP 118121   23:57:35.0   -64:17:53.1                H-coron (~1 hr)
#
#          ra_deg    dec_deg       MAIN_ID RA_2_A_ICRS_J2017_5_2000  \
# 626  356.505000 -40.182472  b'HD 223011'            23 46 01.4123
# 627  357.231667 -28.130278  b'* del Scl'            23 48 55.6799
# 628  357.331667 -27.854139  b'HD 223408'            23 49 19.4270
# 629  359.044583 -39.052333  b'HD 224228'            23 56 10.9830
# 630  359.395833 -64.298083  b'* eta Tuc'            23 57 35.2906
#
#     DEC_2_D_ICRS_2017_5_2000      SP_TYPE         ...           \
# 626            -40 10 57.234  b'A7III/IV'         ...
# ...

# %%
def bytes_to_string(row):
    row['S_Type'] = row['SP_TYPE'].decode('ascii')
    return row

stellarpar = stellarpar.apply(bytes_to_string, axis=1)
# Out:
# 0             A8/9V
# 1               G0V
# 2               F3V
# 3               G2V
# 4           G6V+G7V
# 5               G8V
# 6               F7V
# 7               G8V
# 8               F6V
# 9               F8V
# 10            G2.5V
# 11            A5IVn
# 12             A1Va
# 13            B8/A0
# 14             K4Ve
# 15              F2V
# 16          G1V+K5V
# 17              F7V
# 18     A3VpSrCr_Ksn
# 19            F7/8V
# 20              F7V
# 21               G5
# 22              K0V
# 23              G5V
# 24            K0III
# 25              F7V
# 26              F6V
# 27              G9V
# 28              G7V
# 29              G6V
#            ...
# 601             G0V
# 602       G0VCH-0.3
# 603          F0IV-V
# 604            K4Ve
# 605             A4V
# 606             G5V
# 607             G1V
# 608             F7V
# 609      F0+VkA5mA5
# 610             G8V
# 611             F6V
# 612             G5V
# 613      A2VpSrCrSi
# 614            G8IV
# ...

# %%
del stellarpar['SP_TYPE']

# %%
stellarpar.to_csv('stellarparameters.csv')

# %%
df = pd.read_csv('stellarparameters.csv', index_col=0)

# %%
import numpy as np
def splittype(row):
    try:
        row['Class'] = row["S_Type"][0]
        row['subtype'] = row["S_Type"][1]
    except:
        row['Class'] = np.nan
        row['subtype'] = np.nan
    return row

df = df.apply(splittype, axis=1)
df.tail()
# Out:
#             star           ra           dec                       comment  \
# 626  HIP 117219   23:46:01.2   -40:10:56.9                H-coron (~1 hr)
# 627  HIP 117452   23:48:55.6   -28:07:49.0   H-coron (~1 hr); H-coron-pol
# 628  HIP 117481   23:49:19.6   -27:51:14.9   H-coron (~1 hr); H-coron-pol
# 629  HIP 118008   23:56:10.7   -39:03:08.4   H-coron (~1 hr); H-coron-pol
# 630  HIP 118121   23:57:35.0   -64:17:53.1                H-coron (~1 hr)
#
#          ra_deg    dec_deg       MAIN_ID RA_2_A_ICRS_J2017_5_2000  \
# 626  356.505000 -40.182472  b'HD 223011'            23 46 01.4123
# 627  357.231667 -28.130278  b'* del Scl'            23 48 55.6799
# 628  357.331667 -27.854139  b'HD 223408'            23 49 19.4270
# 629  359.044583 -39.052333  b'HD 224228'            23 56 10.9830
# 630  359.395833 -64.298083  b'* eta Tuc'            23 57 35.2906
#
#     DEC_2_D_ICRS_2017_5_2000  Distance_distance   ...     Fe_H_Teff  \
# ...

# %%
df = df.apply(splittype, axis=1)
df.tail()
# Out:
#             star           ra           dec                       comment  \
# 626  HIP 117219   23:46:01.2   -40:10:56.9                H-coron (~1 hr)
# 627  HIP 117452   23:48:55.6   -28:07:49.0   H-coron (~1 hr); H-coron-pol
# 628  HIP 117481   23:49:19.6   -27:51:14.9   H-coron (~1 hr); H-coron-pol
# 629  HIP 118008   23:56:10.7   -39:03:08.4   H-coron (~1 hr); H-coron-pol
# 630  HIP 118121   23:57:35.0   -64:17:53.1                H-coron (~1 hr)
#
#          ra_deg    dec_deg       MAIN_ID RA_2_A_ICRS_J2017_5_2000  \
# 626  356.505000 -40.182472  b'HD 223011'            23 46 01.4123
# 627  357.231667 -28.130278  b'* del Scl'            23 48 55.6799
# 628  357.331667 -27.854139  b'HD 223408'            23 49 19.4270
# 629  359.044583 -39.052333  b'HD 224228'            23 56 10.9830
# 630  359.395833 -64.298083  b'* eta Tuc'            23 57 35.2906
#
#     DEC_2_D_ICRS_2017_5_2000  Distance_distance   ...     Fe_H_Teff  \
# ...

# %%
Kdwarfs = df[df['Class'] == 'K']
Kdwarfs.shape
# Out:
# (80, 35)

# %%
#Kdwarfs = Kdwarfs[Kdwarfs['subtype'].astype(int) >= 4]
#Kdwarfs.shape

# %%
Kdwarfs.sort_values('Distance_distance')
# Out:
#                 star           ra           dec                       comment  \
# 78          eps Eri   03:32:55.8   -09:27:29.7   H-coron (~1 hr); H-coron-pol
# 587       HD 209100   22:03:21.7   -56:47:10.0                H-coron (~1 hr)
# 604          TW PsA   22:56:24.1   -31:33:56.0                H-coron (~1 hr)
# 65           HR 857   02:52:32.1   -12:46:10.9   H-coron (~1 hr); H-coron-pol
# 217       HIP 42808   08:43:18.0   -38:52:57.0                H-coron (~1 hr)
# 48        HIP 11964   02:34:22.6   -43:47:47.0                H-coron (~1 hr)
# 102        HD 29697   04:41:18.8    20:54:05.4                H-coron (~1 hr)
# 532       HIP 97944   19:54:17.8   -23:56:27.9                H-coron (~1 hr)
# 88        HIP 18512   03:57:28.7   -01:09:34.1                H-coron (~1 hr)
# 125       HIP 25283   05:24:30.1   -38:58:10.2                H-coron (~1 hr)
# 560      HIP 104239   21:07:10.4   -13:55:23.0                H-coron (~1 hr)
# ...

# %%
mag = Kdwarfs[['S_Type', 'Distance_distance', 'FLUX_I', 'FLUX_H', 'Fe_H_Teff']]
mag
# Out:
#         S_Type  Distance_distance  FLUX_I  FLUX_H  Fe_H_Teff
# 14        K4Ve            44.4988   8.238   6.721       4376
# 22         K0V            35.7191     NaN   6.796       5149
# 24       K0III           109.3589   7.893   6.681          0
# 30         K1V            39.8438     NaN   6.944       4720
# 33       K0/1V            24.0441   6.817   5.900       5415
# 48         K7V            11.5373   6.992   5.126       3831
# 57        K6Ve            44.4373   8.807   7.234       4100
# 64         K1V            40.1263   7.815   6.651       4965
# 65         K1V            10.3584   4.890   4.130       5056
# 70        K7Ve            32.2262   8.548   6.852       3900
# 78         K2V             3.2028   2.540   1.750       4999
# 79      K2:Vnk            29.6272   5.000   3.250       4781
# 80         K7V            25.6177     NaN   6.523          0
# 88         K4V            15.3010   6.724   5.486       4696
# ...

# %%
# %matplotlib inline
mag['FLUX_I'].hist()
# Out:
# /Users/dtamayo/miniconda3/envs/p3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
mag['Distance_distance'].hist(bins=50)
# Out:
# /Users/dtamayo/miniconda3/envs/p3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Can do all of these to see what contrast ratios we get. Most will be too close or too far
