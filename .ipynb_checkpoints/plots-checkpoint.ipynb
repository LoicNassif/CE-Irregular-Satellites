# %%
from swarms import SizeDistribution
from swarms import CollSwarm
from numpy import linspace, zeros, logspace, array
import matplotlib.pyplot as plt

# %% [markdown]
# # Jupiter: An Example
#
# For the following plots, the specifications of Jupiter will be used to demonstrate the different possible plots that swarms.py can produce.

# %%
Dmin = 12e-6; Dmax = 15e4; M_init = 7.37307e19

jupiter = SizeDistribution(Dmin, Dmax, M0=M_init)

# %%
initial_swarm_mass = jupiter.Mtot()
initial_swarm_area = jupiter.Atot()
print("Swarm mass = {0:.5e} kg".format(initial_swarm_mass))
print("Swarm area = {0:.5e} m^2".format(initial_swarm_area))
# Out:
# Swarm mass = 7.39324e+19 kg
# Swarm area = 9.18122e+16 m^2

# %% [markdown]
# ## Area Plot
#
# One can plot the total surface area of a swarm over time by repeatedly updating the swarm for every needed time step and record the specific area at that time. There is the option to specify a dynamic maximum object size that would decrease over time as specified in Kennedy 2010.

# %%
M0 = 7.37307e19; Dt = 100.; Dmax = 150000.; L_s = 3.828e26;
M_s = 1.989e30; M_pl = 1.89587112e27; a_pl = 7.7792e11
R_pl = 6.9911e7; eta = 0.4; Nstr = 6.; d_pl = a_pl

jupiter_correct = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=True)
jupiter_no_correct = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=False)

# %%
time = linspace(0, 1e10, 50000)
area_correct = zeros(50000)
area_no_correct = zeros(50000)

for i in range(len(time)):
    a = jupiter_correct.computeAtot()*4.4683677582981e-23 # change units into AU
    b = jupiter_no_correct.computeAtot()*4.4683677582981e-23 # change units into AU
    area_correct[i] = a
    area_no_correct[i] = b
    jupiter_correct.updateSwarm(time[i])
    jupiter_no_correct.updateSwarm(time[i])

# %%
plt.loglog(time, area_correct, 'r', label="corrected stranding evolution")
plt.loglog(time, area_no_correct, ls='--', label="static Dc")
plt.axvline(jupiter_correct.tnleft, color='g', ls='--', label="first stranded object")
plt.xlabel("time [yr]")
plt.ylabel("area [AU^2]")
plt.title("Area of Circumplanetary Swarm - Jupiter")
plt.legend()
plt.xlim([2e5, 9e9])
plt.ylim([5e-9, 1e-5])
plt.show()

# %% [markdown]
# ## Number Density Plot
#
# Since it is possible to compute the number of objects in the swarm at any time with our code, an other possible plot that can be made is a size-distribution plot for logarithmic spaced times.

# %%
jupiter_num = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=True)

# %%
drange = linspace(0.1, 250000, 5000)
time_log = logspace(0, 10, 30)
num_distribution = []
Dc_list = []
for i in range(len(time_log)):
    #jupiter_num.tnleft = 0.5e8
    jupiter_num.updateSwarm(time_log[i])
    num = []
    dcc = []
    for j in range(len(drange)):
        dcc.append(jupiter_num.swarm.Dc)
        num.append(jupiter_num.computen(drange[j]))
    num_distribution.append(num)
    Dc_list.append(dcc)

# %%
drange = array(drange)
for i in range(len(num_distribution)):
    num_dist = []
    prev_drange = []
    for j in range(len(num_distribution[i])):
        #print("drange = ", drange[j])
        #print("Dc = ", Dc_list[j])
        if drange[j] < Dc_list[i][j]:
            prev_drange.append(drange[j])
            num_dist.append(num_distribution[i][j])
    plt.loglog(prev_drange, num_dist)
#plt.loglog(Dc_list)
#print(Dc_list)
plt.xlim([5000, 200000])
plt.ylim([1e-5, 1e-2])
plt.xlabel("size [m]")
plt.ylabel("number density")
plt.title("Number Density in the Circumplanetary Swarm")
plt.show()

# %% [markdown]
# # Observable Quantities

# %% [markdown]
# ## Flux Computations
#
# We now demonstrate the important computations of thermal radiation flux as well as scattering flux produced by both the planet and the circumplanetary swarm. These values are critical, since they are the observable variables. The distance from the solar system, d_pl, used is 10 pc. We take a Jupiter mass planet orbiting an A5 main-sequence star.

# %%
M0 = 10 * 7.34767309e22; Dt = 100.; Dmax = 250000.; L_s = 20 * 3.828e26;
M_s = 1.86 * 1.989e30; M_pl = 1.89587112e27; a_pl = 7.48e12
R_pl = 6.9911e7; eta = 0.4; Nstr = 6.; d_pl = 3.086e17

jupiter5 = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=True)

jupiter5.updateSwarm(1e7) # Update the swarm to 4.5e9 years. 

waverange = logspace(-7, -3, 200)
Fth_planet = jupiter5.computeFth(waverange, planet=True)/1e-26
Fth_swarm = jupiter5.computeFth(waverange, swarm=True)/1e-26
Fs_planet = jupiter5.computeFs(waverange, 1., 0.52, planet=True)/1e-26
Fs_swarm = jupiter5.computeFs(waverange, 0.32, 0.08, swarm=True)/1e-26
# Out:
# C:\Users\loloynage\Documents\CE-Irregular-Satellites\swarms.py:267: RuntimeWarning: overflow encountered in exp
#   b = 1/(exp(h*(c/lamb)/(k_B*T)) - 1)

# %%
plt.figure(3)
plt.title('Planet Flux')
plt.loglog(waverange, Fs_planet, label="Scattered")
plt.loglog(waverange, Fth_planet, label="Thermal")
plt.ylim([10e-11, 10e-3])
plt.legend()
plt.show()

plt.figure(4)
plt.title('Dust Flux')
plt.loglog(waverange, Fs_swarm, label="Scattered")
plt.loglog(waverange, Fth_swarm, label="Thermal")
plt.ylim([10e-11, 10e-3])
plt.legend()
plt.show()

# %% [markdown]
# # Evolution of Debris Population

# %%
M0 = 7.37307e19; Dt = 100.; Dmax = 150000.; L_s = 3.828e26;
M_s = 1.989e30; M_pl = 1.89587112e27; a_pl = 7.7792e11
R_pl = 6.9911e7; eta = 0.4; Nstr = 6.; d_pl = a_pl

jupiter6 = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=True)

drange = linspace(0.01, 1.5e5, 2500)
#drange = logspace(2, 6, 1000)
time_log = logspace(6, 9.5, 10)
total_amount = []
# Testing
# num = []
#print(jupiter6.computeNtot(dlow=1000))
# for j in range(len(drange)):
#    num.append(jupiter6.computeNtot(dlow=drange[j]))
# total_amount.append(num)

for i in range(len(time_log)):
    jupiter6.updateSwarm2(time_log[i])
    num = []
    print(i)
    for d in drange:#j in range(len(drange)):
        Mt = jupiter6.swarm.Mtot(dlow=d, dhigh=Dmax)
        jupiter6.swarm.M0 = Mt
        #jupiter6.swarm.compute_kg_from_Mtot(Mt)
        #jupiter6.swarm.compute_ks_from_kg()
        #jupiter6.updateSwarm2(time_log[i], d)
        #print(jupiter6.swarm.M0)
        num.append(jupiter6.computeNtot(dlow=d)) #Make dhigh explicit
    total_amount.append(num)
# Out:
# 0
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  3418.180317555879
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  9963.994929971988
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  2382.364392785308
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  11824.739103641456
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  841.5386903816875
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  19327.739803921566
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  768.602607061285
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  20168.075882352936
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  429.18316097027406
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  26470.596470588232
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  242.76964539261644
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  34393.765210084035
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  226.77639649804354
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  35474.19731092437
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  163.79569948959954
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  41056.42983193277
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  136.24839401049596
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  44537.82215686274
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  99.55884595129152
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  51020.41476190476
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  68.6088026179123
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  59603.84756302521
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  45.050588110957285
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  70348.14456582633
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  34.87626222011004
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  77310.92921568626
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  28.984939569209814
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  82472.99369747897
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  26.333204757049273
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  85174.07394957982
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  25.999108012571526
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  85534.21798319326
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  18.681597205058516
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  94837.9388515406
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  17.135853565176642
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  97238.89907563024
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  13.021348256495127
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  104681.8757703081
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  9.650782507256025
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  112304.9244817927
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  8.077766941173547
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  116506.60487394956
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  4.744380041785475
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  127310.92588235292
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  3.8771845095881465
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  130672.27019607842
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  3.803092630432032
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  130972.39022408961
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28456943434124.367
# kg_val =  1795511746121.821
# lower =  0
# upper =  3.341117498201706
# str upper =  0.0
# qg =  1.7
# k_str =  24.23240989694942
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  132893.15840336133
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 1
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  27195891351351.715
# kg_val =  1715944738782.076
# lower =  0
# upper =  4820.164973546422
# str upper =  0.0
# qg =  1.7
# k_str =  23.158565439905434
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  8283.322773109243
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  27195891351351.715
# kg_val =  1715944738782.076
# lower =  0
# upper =  505.9538419842141
# str upper =  0.0
# qg =  1.7
# k_str =  23.158565439905434
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  24009.612240896353
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  27195891351351.715
# kg_val =  1715944738782.076
# lower =  0
# upper =  474.8387000800909
# str upper =  0.0
# qg =  1.7
# k_str =  23.158565439905434
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  24729.900308123244
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  27195891351351.715
# kg_val =  1715944738782.076
# lower =  0
# upper =  422.45680670419966
# str upper =  0.0
# qg =  1.7
# k_str =  23.158565439905434
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  26110.452436974785
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  27195891351351.715
# kg_val =  1715944738782.076
# lower =  0
# upper =  369.2325531882891
# str upper =  0.0
# qg =  1.7
# k_str =  23.158565439905434
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  27791.124593837532
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  27195891351351.715
# kg_val =  1715944738782.076
# lower =  0
# upper =  313.902333561499
# str upper =  0.0
# qg =  1.7
# k_str =  23.158565439905434
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  29951.988795518202
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  27195891351351.715
# kg_val =  1715944738782.076
# lower =  0
# upper =  122.90695641705868
# str upper =  0.0
# qg =  1.7
# k_str =  23.158565439905434
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  45678.27826330532
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  27195891351351.715
# kg_val =  1715944738782.076
# lower =  0
# upper =  95.40974982641625
# str upper =  0.0
# qg =  1.7
# k_str =  23.158565439905434
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  50960.39075630252
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ...
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  854541275193.1428
# kg_val =  53917909374.45843
# lower =  0
# upper =  0
# str upper =  18.92016065901575
# qg =  1.7
# k_str =  21.951199796446232
# Dmax =  150000.0
# Dc =  29618.251726673778
# dlow =  82533.01770308122
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  854541275193.1428
# kg_val =  53917909374.45843
# lower =  0
# upper =  0
# str upper =  16.782868556876174
# qg =  1.7
# k_str =  21.951199796446232
# Dmax =  150000.0
# Dc =  29618.251726673778
# dlow =  88295.32224089635
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  854541275193.1428
# kg_val =  53917909374.45843
# lower =  0
# upper =  0
# str upper =  15.996155599951875
# qg =  1.7
# k_str =  21.951199796446232
# Dmax =  150000.0
# Dc =  29618.251726673778
# dlow =  90516.21044817926
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  854541275193.1428
# kg_val =  53917909374.45843
# lower =  0
# upper =  0
# str upper =  10.443512803042454
# qg =  1.7
# k_str =  21.951199796446232
# Dmax =  150000.0
# Dc =  29618.251726673778
# dlow =  107863.14806722688
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  854541275193.1428
# kg_val =  53917909374.45843
# lower =  0
# upper =  0
# str upper =  4.955790168917664
# qg =  1.7
# k_str =  21.951199796446232
# Dmax =  150000.0
# Dc =  29618.251726673778
# dlow =  128271.30997198878
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  854541275193.1428
# kg_val =  53917909374.45843
# lower =  0
# upper =  0
# str upper =  4.485087444909467
# qg =  1.7
# k_str =  21.951199796446232
# Dmax =  150000.0
# Dc =  29618.251726673778
# dlow =  130192.07815126049
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  854541275193.1428
# kg_val =  53917909374.45843
# lower =  0
# upper =  0
# str upper =  3.1275396286277783
# qg =  1.7
# k_str =  21.951199796446232
# Dmax =  150000.0
# Dc =  29618.251726673778
# dlow =  135894.35868347337
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  854541275193.1428
# kg_val =  53917909374.45843
# lower =  0
# upper =  0
# str upper =  2.60040629249176
# qg =  1.7
# k_str =  21.951199796446232
# Dmax =  150000.0
# Dc =  29618.251726673778
# dlow =  138175.27089635853
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc

# %%
print(time_log)
# Out:
# [1.00000000e+06 2.44843675e+06 5.99484250e+06 1.46779927e+07
#  3.59381366e+07 8.79922544e+07 2.15443469e+08 5.27499706e+08
#  1.29154967e+09 3.16227766e+09]

# %%
for i in range(len(total_amount)):
    plt.loglog(drange, total_amount[i], label=i)

plt.legend()
plt.ylim([4e-1, 1e3])
plt.xlim([5e2, 3e5])
plt.show()
