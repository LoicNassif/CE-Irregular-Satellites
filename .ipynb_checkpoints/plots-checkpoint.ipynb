# %%
from swarms import SizeDistribution
from swarms import CollSwarm
from numpy import linspace, zeros, logspace, array
import matplotlib.pyplot as plt

# %% [markdown]
# # Jupiter: An Example
#
# For the following plots, the specifications of Jupiter will be used to demonstrate the different possible plots that swarms.py can produce.

# %%
Dmin = 12e-6; Dmax = 15e4; M_init = 7.37307e19

jupiter = SizeDistribution(Dmin, Dmax, M0=M_init)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-602a24105bac> in <module>()
#       1 Dmin = 12e-6; Dmax = 15e4; M_init = 7.37307e19
#       2
# ----> 3 jupiter = SizeDistribution(Dmin, Dmax, M0=M_init)
#
# NameError: name 'SizeDistribution' is not defined

# %%
initial_swarm_mass = jupiter.Mtot()
initial_swarm_area = jupiter.Atot()
print("Swarm mass = {0:.5e} kg".format(initial_swarm_mass))
print("Swarm area = {0:.5e} m^2".format(initial_swarm_area))
# Out:
# Swarm mass = 7.39324e+19 kg
# Swarm area = 9.18122e+16 m^2

# %% [markdown]
# ## Area Plot
#
# One can plot the total surface area of a swarm over time by repeatedly updating the swarm for every needed time step and record the specific area at that time. There is the option to specify a dynamic maximum object size that would decrease over time as specified in Kennedy 2010.

# %%
M0 = 0.00002 * 7.34767309e22; Dt = 100.; Dmax = 150000.; L_s = 3.828e26;
M_s = 1.989e30; M_pl = 1.89587112e27; a_pl = 7.7792e11
R_pl = 6.9911e7; eta = 0.4; Nstr = 6.; d_pl = a_pl

jupiter_correct = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=True)#, alpha=1.2)
jupiter_no_correct = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=False)#, alpha=1.2)

# %%
time = linspace(0, 1e10, 50000)
area_correct = zeros(50000)
area_no_correct = zeros(50000)

for i in range(len(time)):
    a = jupiter_correct.computeAtot()*4.4683677582981e-23 # change units into AU
    b = jupiter_no_correct.computeAtot()*4.4683677582981e-23 # change units into AU
    area_correct[i] = a
    area_no_correct[i] = b
    jupiter_correct.updateSwarm(time[i])
    jupiter_no_correct.updateSwarm(time[i])

# %%
plt.loglog(time, area_correct, 'r', label="corrected stranding evolution")
plt.loglog(time, area_no_correct, ls='--', label="static Dc")
plt.axvline(jupiter_correct.tnleft, color='g', ls='--', label="first stranded object")
plt.xlabel("time [yr]")
plt.ylabel("area [AU^2]")
plt.title("Area of Circumplanetary Swarm - Jupiter")
plt.legend()
plt.xlim([2e5, 9e9])
plt.ylim([5e-9, 1e-5])
plt.show()

# %% [markdown]
# ## Number Density Plot
#
# Since it is possible to compute the number of objects in the swarm at any time with our code, an other possible plot that can be made is a size-distribution plot for logarithmic spaced times.

# %%
jupiter_num = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=True, alpha=1.2)

# %%
drange = linspace(0.1, 250000, 5000)
time_log = logspace(0, 10, 30)
num_distribution = []
Dc_list = []
for i in range(len(time_log)):
    #jupiter_num.tnleft = 0.5e8
    jupiter_num.updateSwarm(time_log[i])
    num = []
    dcc = []
    for j in range(len(drange)):
        dcc.append(jupiter_num.swarm.Dc)
        num.append(jupiter_num.computen(drange[j]))
    num_distribution.append(num)
    Dc_list.append(dcc)

# %%
drange = array(drange)
for i in range(len(num_distribution)):
    num_dist = []
    prev_drange = []
    for j in range(len(num_distribution[i])):
        #print("drange = ", drange[j])
        #print("Dc = ", Dc_list[j])
        if drange[j] < Dc_list[i][j]:
            prev_drange.append(drange[j])
            num_dist.append(num_distribution[i][j])
    plt.loglog(prev_drange, num_dist)
#plt.loglog(Dc_list)
#print(Dc_list)
plt.xlim([5000, 200000])
plt.ylim([1e-5, 1e-2])
plt.xlabel("size [m]")
plt.ylabel("number density")
plt.title("Number Density in the Circumplanetary Swarm")
plt.show()

# %% [markdown]
# # Observable Quantities

# %% [markdown]
# ## Flux Computations
#
# We now demonstrate the important computations of thermal radiation flux as well as scattering flux produced by both the planet and the circumplanetary swarm. These values are critical, since they are the observable variables. The distance from the solar system, d_pl, used is 10 pc. We take a Jupiter mass planet orbiting an A5 main-sequence star.

# %%
M0 = 10 * 7.34767309e22; Dt = 100.; Dmax = 250000.; L_s = 20 * 3.828e26;
M_s = 1.86 * 1.989e30; M_pl = 1.89587112e27; a_pl = 7.48e12
R_pl = 6.9911e7; eta = 0.4; Nstr = 6.; d_pl = 3.086e17

jupiter5 = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=True)

jupiter5.updateSwarm(1e7) # Update the swarm to 4.5e9 years. 

waverange = logspace(-7, -3, 200)
Fth_planet = jupiter5.computeFth(waverange, planet=True)/1e-26
Fth_swarm = jupiter5.computeFth(waverange, swarm=True)/1e-26
Fs_planet = jupiter5.computeFs(waverange, 1., 0.52, planet=True)/1e-26
Fs_swarm = jupiter5.computeFs(waverange, 0.32, 0.08, swarm=True)/1e-26
# Out:
# C:\Users\loloynage\Documents\CE-Irregular-Satellites\swarms.py:268: RuntimeWarning: overflow encountered in exp
#   b = 1/(exp(h*(c/lamb)/(k_B*T)) - 1)

# %%
plt.figure(3)
plt.title('Planet Flux')
plt.loglog(waverange, Fs_planet, label="Scattered")
plt.loglog(waverange, Fth_planet, label="Thermal")
plt.ylim([10e-11, 10e-3])
plt.legend()
plt.show()

plt.figure(4)
plt.title('Dust Flux')
plt.loglog(waverange, Fs_swarm, label="Scattered")
plt.loglog(waverange, Fth_swarm, label="Thermal")
plt.ylim([10e-11, 10e-3])
plt.legend()
plt.show()

# %% [markdown]
# # Evolution of Debris Population

# %%
M0 = 0.001 * 7.3477e22; Dt = 100.; Dmax = 150000.; L_s = 3.828e26;
M_s = 1.989e30; M_pl = 1.89587112e27; a_pl = 7.7792e11
R_pl = 6.9911e7; eta = 0.4; Nstr = 6.; d_pl = a_pl

jupiter6 = CollSwarm(M0, Dt, Dmax, L_s, M_s, M_pl, a_pl, R_pl, eta, Nstr, d_pl, correction=True, alpha=1.2)

drange = linspace(0.01, 1.5e5, 2500)
drange_Dc_tot = []
#drange = logspace(2, 6, 1000)
time_log = logspace(6, 10, 10)
total_amount = []
# Testing
# num = []
#print(jupiter6.computeNtot(dlow=1000))
# for j in range(len(drange)):
#    num.append(jupiter6.computeNtot(dlow=drange[j]))
# total_amount.append(num)

for i in range(len(time_log)):
    jupiter6.updateSwarm(time_log[i])
    num = []
    drange_Dc = []
    print(i)
    for d in drange:#j in range(len(drange)):
        Xc_val = jupiter6.computeXc()
        Mt = jupiter6.swarm.DMtot(jupiter6.Rcc0, time_log[i], jupiter6.tnleft, Xc_val, jupiter6.M_init, jupiter6.correction)
        jupiter6.swarm.M0 = Mt
        #jupiter6.swarm.compute_kg_from_Mtot(Mt)
        #jupiter6.swarm.compute_ks_from_kg()
        #jupiter6.updateSwarm2(time_log[i], d)
        #print(jupiter6.swarm.M0)
        #if d >= jupiter6.swarm.Dc:
        num.append(jupiter6.computeNtot(dlow=d)) #Make dhigh explicit
        drange_Dc.append(d)
    drange_Dc_tot.append(drange_Dc)
    total_amount.append(num)
# Out:
# 0
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  71569.51233109391
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  2340.946218487395
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  1635.880960341494
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  14105.65131652661
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  1423.0700105048666
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  15066.035406162464
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  1209.7400944191415
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  16266.515518207281
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  909.324752905552
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  18607.451736694675
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  710.8040985598561
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  20888.363949579827
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  413.4642739615855
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  26890.764509803917
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  339.06210851716025
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  29471.796750700276
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  220.21981003928406
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  35894.365350140055
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  132.9185475886213
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  44957.99019607843
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  75.01106159481873
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  57382.95935574229
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  44.19959290642841
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  70768.31260504201
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  36.544084007589596
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  75930.37708683472
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  27.097335717482746
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  84273.7138655462
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  18.780129782802504
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  94597.84282913164
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  17.604468971722497
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  96398.56299719887
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  14.455511036823554
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  101800.72350140054
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  13.608705891378007
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  103421.37165266105
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  8.458951698987272
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  115366.14876750698
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  5.545053509839594
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  124369.74960784311
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  5.424750423929385
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  124789.91764705881
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  5.121094565624274
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  125870.34974789915
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  4.180238957484518
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  129411.76607843135
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  2.716369084362903
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  135594.2386554622
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  1.8098245083882463
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  139915.96705882353
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  28362150143085.5
# kg_val =  1789530693802.9788
# lower =  0
# upper =  1.6907016719165078
# str upper =  0.0
# qg =  1.7
# k_str =  24.15168900402386
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  140516.20711484592
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 1
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  1472598.0685174009
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  540.226050420168
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  205284.19087228525
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  1380.5621288515406
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  488.70650761863817
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  24249.708263305318
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  316.5995456773701
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  29651.868767507
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  221.21806505659245
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  34933.9812605042
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  122.38063901233554
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  45498.206246498594
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  87.69985390587942
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  52521.01490196078
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  84.91994074485073
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  53241.30296918767
# 	 dlow < Dc
# 	 dlow < Dc
# ks_val =  26835848287077.227
# kg_val =  1693227557208.7617
# lower =  0
# upper =  84.46789373748258
# str upper =  0.0
# qg =  1.7
# k_str =  22.851972037340957
# Dmax =  150000.0
# Dc =  150000.0
# dlow =  53361.350980392155
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# 	 dlow < Dc
# ...
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  2.810410417674253
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  88055.22621848738
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  2.69655957819452
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  89975.99439775909
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  2.2029838325264013
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  98799.5232212885
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  2.00172672004232
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  102641.05957983191
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  1.6873146313698455
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  108943.58016806722
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  1.3905899274486264
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  115246.1007563025
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  1.3495308077744435
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  116146.46084033612
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  1.2952776792945935
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  117346.94095238093
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  1.2255724851500707
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  118907.5650980392
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  0.9505527826722028
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  125270.10969187673
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  0.8877267213353471
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  126770.70983193275
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  0.27740968370095015
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  142316.92728291315
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  0.24413605857573048
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  143217.28736694678
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  0.08298890346286569
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  147659.0637815126
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# ks_val =  2034555936.964056
# kg_val =  128371801.11832543
# lower =  0
# upper =  0
# str upper =  0.03176451710145733
# qg =  1.7
# k_str =  3.6570935349030487
# Dmax =  150000.0
# Dc =  3917.562952808411
# dlow =  149099.63991596637
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc
# 	 dlow > Dc

# %%
print(time_log)
# Out:
# [1.00000000e+06 2.78255940e+06 7.74263683e+06 2.15443469e+07
#  5.99484250e+07 1.66810054e+08 4.64158883e+08 1.29154967e+09
#  3.59381366e+09 1.00000000e+10]

# %%
for i in range(len(total_amount)):
    plt.loglog(drange_Dc_tot[i], total_amount[i], label=i)

plt.legend()
plt.ylim([4e-1, 1e3])
plt.xlim([5e2, 3e5])
plt.show()
